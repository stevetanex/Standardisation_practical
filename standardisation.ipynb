# %%
# SD

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# !pip install ydata-profiling
# Out:
# Requirement already satisfied: ydata-profiling in e:\anaconda-2\lib\site-packages (4.18.0)
# Requirement already satisfied: scipy<1.17,>=1.8 in e:\anaconda-2\lib\site-packages (from ydata-profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in e:\anaconda-2\lib\site-packages (from ydata-profiling) (2.2.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in e:\anaconda-2\lib\site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in e:\anaconda-2\lib\site-packages (from ydata-profiling) (2.10.3)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in e:\anaconda-2\lib\site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in e:\anaconda-2\lib\site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in e:\anaconda-2\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in e:\anaconda-2\lib\site-packages (from ydata-profiling) (2.1.3)
# Requirement already satisfied: minify-html>=0.15.0 in e:\anaconda-2\lib\site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in e:\anaconda-2\lib\site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in e:\anaconda-2\lib\site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in e:\anaconda-2\lib\site-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.66.3 in e:\anaconda-2\lib\site-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in e:\anaconda-2\lib\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in e:\anaconda-2\lib\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in e:\anaconda-2\lib\site-packages (from ydata-profiling) (0.14.4)
# Requirement already satisfied: typeguard<5,>=4 in e:\anaconda-2\lib\site-packages (from ydata-profiling) (4.4.4)
# Requirement already satisfied: imagehash==4.3.2 in e:\anaconda-2\lib\site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in e:\anaconda-2\lib\site-packages (from ydata-profiling) (1.9.4)
# Requirement already satisfied: dacite<2,>=1.9 in e:\anaconda-2\lib\site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in e:\anaconda-2\lib\site-packages (from ydata-profiling) (0.61.0)
# Requirement already satisfied: PyWavelets in e:\anaconda-2\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (1.8.0)
# Requirement already satisfied: pillow in e:\anaconda-2\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\anaconda-2\lib\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in e:\anaconda-2\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in e:\anaconda-2\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\anaconda-2\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\anaconda-2\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in e:\anaconda-2\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\anaconda-2\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in e:\anaconda-2\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in e:\anaconda-2\lib\site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in e:\anaconda-2\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in e:\anaconda-2\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in e:\anaconda-2\lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\anaconda-2\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in e:\anaconda-2\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in e:\anaconda-2\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\anaconda-2\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\anaconda-2\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\anaconda-2\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\anaconda-2\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2025.4.26)
# Requirement already satisfied: patsy>=0.5.6 in e:\anaconda-2\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# Requirement already satisfied: colorama in e:\anaconda-2\lib\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in e:\anaconda-2\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (24.3.0)
# Requirement already satisfied: networkx>=2.4 in e:\anaconda-2\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.4.2)
# Requirement already satisfied: puremagic in e:\anaconda-2\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (1.30)
# Requirement already satisfied: six>=1.5 in e:\anaconda-2\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)

# %%
from ydata_profiling import ProfileReport
prof=ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# %|                                                                                           | 0/12 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 92.55it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df1=pd.read_csv('Social_Network_Ads.csv')
df1.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df2=df1.iloc[:,2:]
df2.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
df2.sample(5)
# Out:
#      Age  EstimatedSalary  Purchased
# 52    29            83000          0
# 245   51           146000          1
# 41    33            51000          0
# 371   60            83000          1
# 0     19            19000          0

# %%
x=df2.iloc[:,:2]
y=df2.iloc[:,2:3]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.3,random_state=0)
X_train.shape,X_test.shape
# Out:
# ((280, 2), (120, 2))

# %%
# Standardisation

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(X_train)
X_train_s=scaler.transform(X_train)
X_test_s=scaler.transform(X_test)

# %%
X_train_s
# Out:
# array([[-1.1631724 , -1.5849703 ],
#        [ 2.17018137,  0.93098672],
#        [ 0.0133054 ,  1.22017719],
#        [ 0.20938504,  1.07558195],
#        [ 0.40546467, -0.48604654],
#        [-0.28081405, -0.31253226],
#        [ 0.99370357, -0.8330751 ],
#        [ 0.99370357,  1.8563962 ],
#        [ 0.0133054 ,  1.24909623],
#        [-0.86905295,  2.26126285],
#        [-1.1631724 , -1.5849703 ],
#        [ 2.17018137, -0.80415605],
#        [-1.35925203, -1.46929411],
#        [ 0.40546467,  2.2901819 ],
#        [ 0.79762394,  0.75747245],
#        [-0.96709276, -0.31253226],
#        [ 0.11134522,  0.75747245],
#        [-0.96709276,  0.55503912],
#        [ 0.30742485,  0.06341534],
#        [ 0.69958412, -1.26686079],
#        [-0.47689368, -0.0233418 ],
#        [-1.7514113 ,  0.3526058 ],
#        [-0.67297331,  0.12125343],
#        [ 0.40546467,  0.29476771],
#        [-0.28081405,  0.06341534],
#        [-0.47689368,  2.2901819 ],
#        [ 0.20938504,  0.03449629],
#        [ 1.28782302,  2.20342476],
#        [ 0.79762394,  0.26584866],
#        [-0.28081405,  0.15017248],
#        [ 0.0133054 , -0.54388463],
#        [-0.18277423,  0.15017248],
#        [-0.08473441,  0.23692961],
#        [ 0.0133054 , -0.25469417],
#        [ 2.17018137,  1.104501  ],
#        [-1.7514113 ,  0.3526058 ],
#        [ 1.87606192,  0.12125343],
#        [ 0.40546467, -0.13901799],
#        [-1.1631724 ,  0.29476771],
#        [ 0.79762394,  1.36477242],
#        [-0.28081405, -0.25469417],
#        [-1.65337148, -0.05226085],
#        [-0.96709276, -0.74631796],
#        [ 0.30742485,  0.49720103],
#        [-0.08473441, -1.06442747],
#        [-1.06513258,  0.58395817],
#        [ 0.11134522, -0.80415605],
#        [-0.96709276,  1.53828669],
#        [-0.67297331,  1.39369146],
#        [-1.26121221,  0.49720103],
#        [-0.28081405,  0.03449629],
#        [-0.08473441,  0.00557724],
#        [-0.28081405, -0.89091319],
#        [ 0.89566375, -1.35361793],
#        [-0.28081405,  2.2323438 ],
#        [ 0.99370357,  1.97207239],
#        [-1.1631724 ,  0.46828198],
#        [-1.26121221,  0.26584866],
#        [-1.06513258, -0.37037036],
#        [ 0.0133054 ,  0.03449629],
#        [ 0.11134522, -0.25469417],
#        [-1.55533166, -1.23794174],
#        [-0.47689368, -0.28361322],
#        [ 0.99370357,  0.12125343],
#        [ 1.97410174, -1.35361793],
#        [ 1.48390265,  0.06341534],
#        [-0.5749335 ,  1.36477242],
#        [ 1.58194247,  0.00557724],
#        [-0.77101313,  0.29476771],
#        [ 1.97410174,  0.7285534 ],
#        [-1.1631724 , -0.51496559],
#        [ 0.69958412,  0.26584866],
#        [-1.35925203, -0.42820845],
#        [ 0.20938504,  0.15017248],
#        [-0.47689368, -1.2090227 ],
#        [ 0.6015443 ,  2.00099143],
#        [-1.55533166, -1.49821316],
#        [-0.47689368, -0.54388463],
#        [ 0.50350449,  1.82747716],
#        [-1.35925203, -1.09334651],
#        [ 0.79762394, -1.38253697],
#        [-0.28081405, -0.42820845],
#        [ 1.58194247,  0.98882482],
#        [ 0.99370357,  1.42261051],
#        [-0.28081405, -0.48604654],
#        [-0.08473441,  2.14558666],
#        [-1.45729185, -0.11009894],
#        [-0.08473441,  1.94315334],
#        [-0.67297331, -0.34145131],
#        [-0.47689368, -0.8330751 ],
#        [ 0.69958412, -1.38253697],
#        [-0.77101313, -1.5849703 ],
#        [-1.84945111, -1.46929411],
#        [ 1.09174339,  0.12125343],
#        [ 0.11134522,  1.50936765],
#        [-0.28081405,  0.09233438],
#        [ 0.11134522,  0.03449629],
#        [-1.35925203, -1.35361793],
#        [ 0.30742485,  0.06341534],
#        [-0.86905295,  0.38152485],
#        [ 1.58194247, -1.26686079],
#        [-0.28081405, -0.74631796],
#        [-0.08473441,  0.15017248],
#        [-0.86905295, -0.65956082],
#        [-0.67297331, -0.05226085],
#        [ 0.40546467, -0.45712749],
#        [-0.77101313,  1.88531525],
#        [ 1.38586284,  1.27801528],
#        [ 1.1897832 , -0.97767033],
#        [ 1.7780221 ,  1.82747716],
#        [-0.86905295, -0.25469417],
#        [-0.77101313,  0.55503912],
#        [-1.1631724 , -1.55605125],
#        [-0.47689368, -1.12226556],
#        [ 0.30742485,  0.06341534],
#        [-0.18277423, -1.06442747],
#        [ 1.67998229,  1.59612479],
#        [ 0.99370357,  1.76963906],
#        [ 0.30742485,  0.03449629],
#        [-0.77101313, -0.22577513],
#        [-0.08473441,  0.06341534],
#        [ 0.30742485, -0.19685608],
#        [ 1.97410174, -0.65956082],
#        [-0.77101313,  1.33585337],
#        [-1.7514113 , -0.60172273],
#        [-0.08473441,  0.12125343],
#        [ 0.30742485, -0.31253226],
#        [ 1.09174339,  0.55503912],
#        [-0.96709276,  0.26584866],
#        [ 1.48390265,  0.3526058 ],
#        [ 0.20938504, -0.37037036],
#        [ 2.17018137, -1.03550842],
#        [-0.28081405,  1.104501  ],
#        [-1.65337148,  0.06341534],
#        [ 0.0133054 ,  0.03449629],
#        [ 0.11134522,  1.04666291],
#        [-0.08473441, -0.37037036],
#        [-1.1631724 ,  0.06341534],
#        [-0.28081405, -1.35361793],
#        [ 1.58194247,  1.104501  ],
#        [-0.77101313, -1.52713221],
#        [ 0.11134522,  1.8563962 ],
#        [-0.86905295, -0.775237  ],
#        [-0.47689368, -0.775237  ],
#        [-0.28081405, -0.91983223],
#        [ 0.30742485, -0.71739891],
#        [ 0.30742485,  0.06341534],
#        [ 0.11134522,  1.8563962 ],
#        [-1.06513258,  1.94315334],
#        [-1.65337148, -1.55605125],
#        [-1.1631724 , -1.09334651],
#        [-0.67297331, -0.11009894],
#        [ 0.11134522,  0.09233438],
#        [ 0.30742485,  0.26584866],
#        [ 0.89566375, -0.57280368],
#        [ 0.30742485, -1.1511846 ],
#        [-0.08473441,  0.67071531],
#        [ 2.17018137, -0.68847986],
#        [-1.26121221, -1.38253697],
#        [-0.96709276, -0.94875128],
#        [ 0.0133054 , -0.42820845],
#        [-0.18277423, -0.45712749],
#        [-1.7514113 , -0.97767033],
#        [ 1.7780221 ,  0.98882482],
#        [ 0.20938504, -0.37037036],
#        [ 0.40546467,  1.104501  ],
#        [-1.7514113 , -1.35361793],
#        [ 0.20938504, -0.13901799],
#        [ 0.89566375, -1.44037507],
#        [-1.94749093,  0.46828198],
#        [-0.28081405,  0.26584866],
#        [ 1.87606192, -1.06442747],
#        [-0.37885386,  0.06341534],
#        [ 1.09174339, -0.89091319],
#        [-1.06513258, -1.12226556],
#        [-1.84945111,  0.00557724],
#        [ 0.11134522,  0.26584866],
#        [-1.1631724 ,  0.32368675],
#        [-1.26121221,  0.29476771],
#        [-0.96709276,  0.43936294],
#        [ 1.67998229, -0.89091319],
#        [ 1.1897832 ,  0.52612008],
#        [ 1.09174339,  0.52612008],
#        [ 1.38586284,  2.31910094],
#        [-0.28081405, -0.13901799],
#        [ 0.40546467, -0.45712749],
#        [-0.37885386, -0.775237  ],
#        [-0.08473441, -0.51496559],
#        [ 0.99370357, -1.1511846 ],
#        [-0.86905295, -0.775237  ],
#        [-0.18277423, -0.51496559],
#        [-1.06513258, -0.45712749],
#        [-1.1631724 ,  1.39369146]])

# %%
X_train_s=pd.DataFrame(X_train_s,columns=X_train.columns)
X_test_s=pd.DataFrame(X_test_s,columns=X_test.columns)

# %%
X_test_s
# Out:
#           Age  EstimatedSalary
# 0   -0.771013         0.497201
# 1    0.013305        -0.572804
# 2   -0.280814         0.150172
# 3   -0.771013         0.265849
# 4   -0.280814        -0.572804
# ..        ...              ...
# 115  1.091743        -0.139018
# 116  0.699584         1.769639
# 117 -0.672973         0.555039
# 118  0.797624         0.352606
# 119  0.895664        -0.543885
#
# [120 rows x 2 columns]

# %%
np.round(X_train.describe())
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean    38.0          69807.0
# std     10.0          34641.0
# min     18.0          15000.0
# 25%     30.0          43000.0
# 50%     37.0          70500.0
# 75%     46.0          88000.0
# max     60.0         150000.0

# %%
np.round(X_train_s.describe())
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean     0.0              0.0
# std      1.0              1.0
# min     -2.0             -2.0
# 25%     -1.0             -1.0
# 50%     -0.0              0.0
# 75%      1.0              1.0
# max      2.0              2.0

# %%
# To understand the accuracy

# %%
from sklearn.linear_model import LogisticRegression

lr=LogisticRegression()
lr_scaled=LogisticRegression()

lr.fit(X_train,Y_train)
lr_scaled.fit(X_train_s,Y_train)

actual=lr.predict(X_test)
scaled=lr_scaled.predict(X_test_s)
# Out:
# E:\anaconda-2\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# E:\anaconda-2\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.metrics import accuracy_score
a=accuracy_score(Y_test,actual)
scaled=accuracy_score(Y_test,scaled)

print("Actual is ",a)
print("Scaled is",scaled)
# Out:
# Actual is  0.875
# Scaled is 0.8666666666666667
